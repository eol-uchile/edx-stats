# %% [markdown]
# # Explorando Stats
#
# En este documento se parsea y revisan los logs de eol.

# %%
import pandas as pd
import numpy as np
import json

# %%
course_json = json.load(open("redes-structure.json"))
course_df = pd.DataFrame.from_records(course_json["blocks"])
course_struct = course_df.T

# %%
def expand_list(df, list_column, new_column):
    """Expand a DataFrame with a column of list values.
    
    Source: https://medium.com/@johnadungan/expanding-lists-in-panda-dataframes-2724803498f8
    
    Arguments:
        df {pandas.core.frame.DataFrame} -- DataFrame with a column to expand
        list_column {str} -- name of the column (whose values are lists) to expand
        new_column {str} -- new name of the column
    Returns:
        pandas.core.frame.DataFrame -- DataFrame with list_column expanded
    """
    lens_of_lists = df[list_column].apply(len)
    max_len = max(lens_of_lists)
    origin_rows = range(df.shape[0])
    destination_rows = np.repeat(origin_rows, lens_of_lists)
    non_list_cols = (
        [idx for idx, col in enumerate(df.columns)
         if col != list_column]
    )
    expanded_df = df.iloc[destination_rows, non_list_cols].copy()
    expanded_df[new_column] = (
        [item for items in df[list_column] for item in items]
    )
    expanded_df[new_column+'_number'] = (
        [n for items in df[list_column]
            for item, n in zip(items, range(1, max_len + 1))]
    )
    expanded_df.reset_index(inplace=True, drop=True)
    return expanded_df

# %%
# 'type', 'block_id', 'student_view_url', 'lms_web_url', 'id', 'display_name', 'child', 'child_number'
course_children = expand_list(course_struct.dropna(), "children", "child")
#'index', 'type', 'block_id', 'student_view_url', 'lms_web_url','children', 'id', 'display_name'
course_no_children = course_struct[course_struct["children"].isna()].copy().reset_index()
# The id of terminal nodes at any level
course_no_children_name = course_no_children[['id', "display_name"]]
# Course child name number is: the id of the parent block and the child id + data
course_child_name = course_children[['id', 'child', 'display_name']].copy()
# Merge them
block_child_name = pd.concat([course_child_name, course_no_children_name], ignore_index=True, sort=True)
# Add what we know
block_father_name = block_child_name.copy().rename(columns={'id': 'father', 'child': 'id'})
# Start adding fathers to the left column
merged_course_structure = block_father_name.merge(block_child_name, on='id')\
        .rename(columns={'father': 'father_x', 'id': 'father_y', 'child': 'id'})\
        .merge(block_child_name, on='id')\
        .rename(columns={'id': 'father_z', 'child': 'id', 'display_name': 'display_name_z'})\
        .merge(block_child_name, on='id')\
        .rename(columns={'id': 'father_w', 'child': 'id', 'display_name': 'display_name_w'})\
        .merge(block_child_name, on='id')
# Recover and rename the columns
valuable_columns = [
        'father_x', 'display_name_x', 'father_y', 'display_name_y', 'father_z', 'display_name_z',
        'father_w', 'display_name_w', 'id']
columns_name = {
        'father_x': 'course',
        'father_y': 'chapter',
        'father_z': 'sequential',
        'father_w': 'vertical',
        'display_name_x': 'course_name',
        'display_name_y': 'chapter_name',
        'display_name_z': 'sequential_name',
        'display_name_w': 'vertical_name',
        'display_name': 'name'
    }
merged_course_structure = merged_course_structure[valuable_columns].rename(
        columns=columns_name)
# Add the missing types from course_no_children (terminal nodes)
course_structure = merged_course_structure.merge(course_children[['child', 'child_number']], left_on='vertical', right_on='child')\
        .drop(columns=['child']).rename(columns={'child_number': 'vertical_number'})\
        .merge(course_children[['child', 'child_number']], left_on='sequential', right_on='child')\
        .drop(columns=['child']).rename(columns={'child_number': 'sequential_number'})\
        .merge(course_children[['child', 'child_number']], left_on='chapter', right_on='child')\
        .drop(columns=['child']).rename(columns={'child_number': 'chapter_number'})\
        .merge(course_children[['child', 'child_number']], left_on='id', right_on='child')\
        .drop(columns=['child'])\
        .astype({'vertical_number': 'int64', 'child_number': 'int64','sequential_number': 'int64','chapter_number': 'int64'})\
        .merge(course_no_children[['index', 'type',"student_view_url","lms_web_url"]], left_on='id', right_on='index')\
        .drop(columns="index")


course_structure.to_csv('course_structure.csv', sep='\t')
course_structure
# Out:
#     Semana 9-10: Redes IP
# 41                              Semana 9-10: Redes IP
# 42                              Semana 9-10: Redes IP
# 43                              Semana 9-10: Redes IP
# 44                              Semana 9-10: Redes IP
# 45                              Semana 9-10: Redes IP
# 46                              Semana 9-10: Redes IP
# 47                              Semana 9-10: Redes IP
# 48                              Semana 9-10: Redes IP
# 49     Semana 11-12: Sistemas Autónomos y Ruteo (BGP)
# 50                               Semana 13: Seguridad
#
#                                              vertical  \
# 0   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 1   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 2   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 3   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 4   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 5   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 6   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 7   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 8   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 9   block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 10  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 11  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 12  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 13  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 14  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 15  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 16  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 17  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 18  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 19  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 20  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 21  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 22  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 23  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 24  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 25  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 26  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 27  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 28  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 29  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 30  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 31  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 32  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 33  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 34  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 35  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 36  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 37  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 38  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 39  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 40  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 41  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 42  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 43  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 44  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 45  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 46  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 47  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 48  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 49  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 50  block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
#
#                                         vertical_name  \
# 0                                 Vídeo de bienvenida
# 1                                       PDF: Programa
# 2   Vídeo: Introducción. Internet. Infraestructura...
# 3                                              Slides
# 4                                   Material de Apoyo
# 5                                        Clase Online
# 6                                                Quiz
# 7                                              Taller
# 8                                              Taller
# 9                      Evaluación - Probemos el Proxy
# 10                                  Material de apoyo
# 11                                       Clase Online
# 12  Vídeo: DNS: Servicio de nombres - Árbol de dom...
# 13  Vídeo: DNS: Servicio de nombres - Delegación d...
# 14                             Vídeo: DNS: Resolución
# 15                                          Actividad
# 16                          Foro de dudas y consultas
# 17                          Probemos nuestro Resolver
# 18                                           Auxiliar
# 19                                     Clase en Video
# 20                                             Slides
# 21                                          Actividad
# 22                                               Foro
# 23                                             Slides
# 24                       Video: Transmisión confiable
# 25                            Video: Sliding window I
# 26                           Video: Sliding window II
# 27                        Video: Números de secuencia
# 28                                               Quiz
# 29                                          Actividad
# 30                                             Slides
# 31                                         Video: TCP
# 32                       Video: Ventana de congestión
# 33                        Video: Formato del segmento
# 34                            Video: Control de flujo
# 35                          Video: Envío de segmentos
# 36                                               Quiz
# 37                                          Actividad
# 38                                               Foro
# 39                                Video: Capas de red
# 40                                 Video: Direcciones
# 41             Slides IP: Ruteo y Circuitos Virtuales
# 42        Slides IPv4: Definición, MTU, Fragmentación
# 43                   Slides IPv4: Máscaras y subredes
# 44                                               Quiz
# 45                                          Actividad
# 46                                          Actividad
# 47                                          Actividad
# 48                                          Actividad
# 49                         Video: Ruteo Externo (BGP)
# 50                                   Video: Seguridad
#
#                                                    id  vertical_number  \
# 0   block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                1
# 1   block-v1:UChile+LEIT01+2020_T2+type@html+block...                1
# 2   block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                1
# 3   block-v1:UChile+LEIT01+2020_T2+type@google-doc...                1
# 4   block-v1:UChile+LEIT01+2020_T2+type@google-doc...                1
# 5   block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                2
# 6   block-v1:UChile+LEIT01+2020_T2+type@problem+bl...                3
# 7   block-v1:UChile+LEIT01+2020_T2+type@html+block...                4
# 8   block-v1:UChile+LEIT01+2020_T2+type@discussion...                4
# 9   block-v1:UChile+LEIT01+2020_T2+type@problem+bl...                5
# 10  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                1
# 11  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                2
# 12  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                3
# 13  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                4
# 14  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                5
# 15  block-v1:UChile+LEIT01+2020_T2+type@html+block...                2
# 16  block-v1:UChile+LEIT01+2020_T2+type@discussion...                3
# 17  block-v1:UChile+LEIT01+2020_T2+type@problem+bl...                4
# 18  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                1
# 19  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                1
# 20  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                2
# 21  block-v1:UChile+LEIT01+2020_T2+type@html+block...                3
# 22  block-v1:UChile+LEIT01+2020_T2+type@discussion...                4
# 23  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                2
# 24  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                3
# 25  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                4
# 26  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                5
# 27  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                6
# 28  block-v1:UChile+LEIT01+2020_T2+type@problem+bl...                7
# 29  block-v1:UChile+LEIT01+2020_T2+type@html+block...                8
# 30  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                1
# 31  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                2
# 32  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                3
# 33  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                4
# 34  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                5
# 35  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                6
# 36  block-v1:UChile+LEIT01+2020_T2+type@problem+bl...                7
# 37  block-v1:UChile+LEIT01+2020_T2+type@html+block...                8
# 38  block-v1:UChile+LEIT01+2020_T2+type@discussion...                9
# 39  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                1
# 40  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                2
# 41  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                3
# 42  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                4
# 43  block-v1:UChile+LEIT01+2020_T2+type@google-doc...                5
# 44  block-v1:UChile+LEIT01+2020_T2+type@problem+bl...                6
# 45  block-v1:UChile+LEIT01+2020_T2+type@html+block...                7
# 46  block-v1:UChile+LEIT01+2020_T2+type@html+block...                8
# 47  block-v1:UChile+LEIT01+2020_T2+type@html+block...                9
# 48  block-v1:UChile+LEIT01+2020_T2+type@html+block...               10
# 49  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                1
# 50  block-v1:UChile+LEIT01+2020_T2+type@video+bloc...                1
#
#     sequential_number  chapter_number  child_number             type  \
# 0                   1               1             1            video
# 1                   2               1             1             html
# 2                   3               1             1            video
# 3                   4               1             1  google-document
# 4                   1               2             1  google-document
# 5                   1               2             1            video
# 6                   1               2             1          problem
# 7                   1               2             1             html
# 8                   1               2             2       discussion
# 9                   1               2             1          problem
# 10                  2               2             1  google-document
# 11                  2               2             1            video
# 12                  2               2             1            video
# 13                  2               2             1            video
# 14                  2               2             1            video
# 15                  3               2             1             html
# 16                  3               2             1       discussion
# 17                  3               2             1          problem
# 18                  4               2             1  google-document
# 19                  1               3             1            video
# 20                  1               3             1  google-document
# 21                  1               3             1             html
# 22                  1               3             1       discussion
# 23                  2               3             1  google-document
# 24                  2               3             1            video
# 25                  2               3             1            video
# 26                  2               3             1            video
# 27                  2               3             1            video
# 28                  2               3             1          problem
# 29                  2               3             1             html
# 30                  3               3             1  google-document
# 31                  3               3             1            video
# 32                  3               3             1            video
# 33                  3               3             1            video
# 34                  3               3             1            video
# 35                  3               3             1            video
# 36                  3               3             1          problem
# 37                  3               3             1             html
# 38                  3               3             1       discussion
# 39                  1               4             1            video
# 40                  1               4             1            video
# 41                  1               4             1  google-document
# 42                  1               4             1  google-document
# 43                  1               4             1  google-document
# 44                  1               4             1          problem
# 45                  1               4             1             html
# 46                  1               4             1             html
# 47                  1               4             1             html
# 48                  1               4             1             html
# 49                  2               4             1            video
# 50                  1               5             1            video
#
#                                      student_view_url  \
# 0   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 1   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 2   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 3   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 4   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 5   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 6   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 7   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 8   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 9   https://eol.andhael.cl/xblock/block-v1:UChile+...
# 10  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 11  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 12  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 13  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 14  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 15  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 16  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 17  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 18  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 19  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 20  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 21  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 22  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 23  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 24  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 25  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 26  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 27  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 28  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 29  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 30  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 31  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 32  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 33  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 34  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 35  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 36  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 37  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 38  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 39  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 40  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 41  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 42  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 43  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 44  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 45  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 46  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 47  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 48  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 49  https://eol.andhael.cl/xblock/block-v1:UChile+...
# 50  https://eol.andhael.cl/xblock/block-v1:UChile+...
#
#                                           lms_web_url
# 0   https://eol.andhael.cl/courses/course-v1:UChil...
# 1   https://eol.andhael.cl/courses/course-v1:UChil...
# 2   https://eol.andhael.cl/courses/course-v1:UChil...
# 3   https://eol.andhael.cl/courses/course-v1:UChil...
# 4   https://eol.andhael.cl/courses/course-v1:UChil...
# 5   https://eol.andhael.cl/courses/course-v1:UChil...
# 6   https://eol.andhael.cl/courses/course-v1:UChil...
# 7   https://eol.andhael.cl/courses/course-v1:UChil...
# 8   https://eol.andhael.cl/courses/course-v1:UChil...
# 9   https://eol.andhael.cl/courses/course-v1:UChil...
# 10  https://eol.andhael.cl/courses/course-v1:UChil...
# 11  https://eol.andhael.cl/courses/course-v1:UChil...
# 12  https://eol.andhael.cl/courses/course-v1:UChil...
# 13  https://eol.andhael.cl/courses/course-v1:UChil...
# 14  https://eol.andhael.cl/courses/course-v1:UChil...
# 15  https://eol.andhael.cl/courses/course-v1:UChil...
# 16  https://eol.andhael.cl/courses/course-v1:UChil...
# 17  https://eol.andhael.cl/courses/course-v1:UChil...
# 18  https://eol.andhael.cl/courses/course-v1:UChil...
# 19  https://eol.andhael.cl/courses/course-v1:UChil...
# 20  https://eol.andhael.cl/courses/course-v1:UChil...
# 21  https://eol.andhael.cl/courses/course-v1:UChil...
# 22  https://eol.andhael.cl/courses/course-v1:UChil...
# 23  https://eol.andhael.cl/courses/course-v1:UChil...
# 24  https://eol.andhael.cl/courses/course-v1:UChil...
# 25  https://eol.andhael.cl/courses/course-v1:UChil...
# 26  https://eol.andhael.cl/courses/course-v1:UChil...
# 27  https://eol.andhael.cl/courses/course-v1:UChil...
# 28  https://eol.andhael.cl/courses/course-v1:UChil...
# 29  https://eol.andhael.cl/courses/course-v1:UChil...
# 30  https://eol.andhael.cl/courses/course-v1:UChil...
# 31  https://eol.andhael.cl/courses/course-v1:UChil...
# 32  https://eol.andhael.cl/courses/course-v1:UChil...
# 33  https://eol.andhael.cl/courses/course-v1:UChil...
# 34  https://eol.andhael.cl/courses/course-v1:UChil...
# 35  https://eol.andhael.cl/courses/course-v1:UChil...
# 36  https://eol.andhael.cl/courses/course-v1:UChil...
# 37  https://eol.andhael.cl/courses/course-v1:UChil...
# 38  https://eol.andhael.cl/courses/course-v1:UChil...
# 39  https://eol.andhael.cl/courses/course-v1:UChil...
# 40  https://eol.andhael.cl/courses/course-v1:UChil...
# 41  https://eol.andhael.cl/courses/course-v1:UChil...
# 42  https://eol.andhael.cl/courses/course-v1:UChil...
# 43  https://eol.andhael.cl/courses/course-v1:UChil...
# 44  https://eol.andhael.cl/courses/course-v1:UChil...
# 45  https://eol.andhael.cl/courses/course-v1:UChil...
# 46  https://eol.andhael.cl/courses/course-v1:UChil...
# 47  https://eol.andhael.cl/courses/course-v1:UChil...
# 48  https://eol.andhael.cl/courses/course-v1:UChil...
# 49  https://eol.andhael.cl/courses/course-v1:UChil...
# 50  https://eol.andhael.cl/courses/course-v1:UChil...

# %%
with open("./back/DCC-CC4303_v1.json") as f:
    l = f.readlines()

records = [json.loads(el) for el in l]
# Clean context and event
expanded = []
for r in records:
    context = r["context"]
    n = r.copy()
    del n["context"]
    for c in context.keys():
        n["context."+c] = context[c]
    if "context.module" in n:
        n["context.display_name"] = n["context.module"]["display_name"]
        del n["context.module"]
    try:
        del n["context.asides"]
        del n["context.user_tags"]
    except:
        pass
    expanded.append(n)

# %%
import pandas as pd
import numpy as np
import re
import os, sys
import glob
import datetime
from datetime import timedelta
from filter_logs import filter_by_log_qty, filter_course_team
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

BASE_DIR = os.path.dirname(os.getcwd())
DATA_DIR = os.path.join(BASE_DIR, 'eol-stats')
SRC_DIR = os.path.join(BASE_DIR, '')
TIMEOUT = timedelta(minutes=10)
LOWER_LIMIT = timedelta(seconds=15)# files
course_file = os.path.join(DATA_DIR, 'course_structure.csv')# load full logs
logs_full = pd.DataFrame.from_records(expanded)
logs = filter_course_team(logs_full, other_people=['gap','francisco_sereno'])
print('Cantidad de logs sin equipo del curso: ' , len(logs))
logs = filter_by_log_qty(logs, min_logs=15)
print('Cantidad de logs luego de filtrar personas con pocos logs: ',len(logs))
logs_full["context.display_name"].dropna()
# Out:
# Cantidad de logs sin equipo del curso:  16649
# Cantidad de logs luego de filtrar personas con pocos logs:  16629
# 429                          Checkboxes
# 430                          Checkboxes
# 436                          Checkboxes
# 447                          Checkboxes
# 448                          Checkboxes
#                       ...
# 23956                            Repaso
# 23960                            Repaso
# 23961                            Repaso
# 24001    Slides IP: Circuitos Virtuales
# 24024    Slides IP: Circuitos Virtuales
# Name: context.display_name, Length: 860, dtype: object

# %%
from LogParser import LogParser# Crear el parser de logs
parser = LogParser(course_filepath=course_file)
parser.load_logs(logs)
parsed_logs = parser.parse_and_get_logs()

# %%
parsed_logs["event_type_vertical"]
# Out:
# 1000                                                   NaN
# 1001                                        NOT_CLASSIFIED
# 1102                                                   NaN
# 1103                                        NOT_CLASSIFIED
# 1104                                        NOT_CLASSIFIED
#                                ...
# 24124    block-v1:UChile+LEIT01+2020_T2+type@vertical+b...
# 24125                                       NOT_CLASSIFIED
# 24126                                             NO_MATCH
# 24127                                       NOT_CLASSIFIED
# 24128                                       NOT_CLASSIFIED
# Name: event_type_vertical, Length: 16629, dtype: object
